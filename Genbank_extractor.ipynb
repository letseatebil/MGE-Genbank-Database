# %%
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.SeqFeature import SeqFeature, FeatureLocation

#Specify transposable element keywords/terms
te_keywords = ["transposase"]

#Specify the multi-GenBank file containing annotations
multigenbank_file = "/Users/xanderlee/Desktop/Honours/Database/Archive_Database/TnCentral_Database/TnCentral_Genbank_Files/TnCentral_Genbank.gbff"

#List to store relevant TE annotations
te_annotations = []

#Parse the multi-GenBank file and extract relevant TE annotations
for index, record in enumerate(SeqIO.parse(multigenbank_file, "genbank")):

    #Get the date or set default to "unknown"
    record_date = record.annotations.get("date", "unknown")

    #Get the topology or set default to "unknown"
    topology = record.annotations.get("topology", "unknown")

    #Get the taxonomy or set default to ["unknown"]
    taxonomy = record.annotations.get("taxonomy", "unknown")

    #Get the source or set default to "unknown"
    source = record.annotations.get("source", "unknown")

    #Get the data file division or set default to "unknown"
    data_file_division = record.annotations.get("data_file_division", "unknown")

    for feature in record.features:
        if feature.type == "CDS" and any(kw in feature.qualifiers.get("product", [""])[0].lower() for kw in te_keywords):
            #Extract the feature's sequence and create a new SeqRecord
            feature_seq = feature.extract(record)

            #Extract accession number
            accession = record.id.split(".")[0]

            #Get the 'product' information from the CDS feature
            product = feature.qualifiers.get("product", "unknown")[0]

            #Extract the 'start' and 'end' positions from the CDS feature
            start = feature.location.start
            end = feature.location.end

            #Check if the feature is on the complement strand
            if feature.location.strand == -1:
                #Create a complement SeqFeature for the CDS
                cds_feature = SeqFeature(
                    FeatureLocation(start=start, end=end),
                    type="CDS",
                    #Set strand to -1 (complement)
                    strand=-1,  
                    qualifiers={"product": product}
                )
            else:
                #Create a SeqFeature for the CDS
                cds_feature = SeqFeature(
                    FeatureLocation(start=start, end=end),
                    type="CDS",
                    qualifiers={"product": product}
                )

            #Create new record for each genbank entry
            new_record = SeqRecord(
                seq = feature_seq.seq,
                id = accession,
                description = product,
                annotations = {
                    "molecule_type": "DNA",
                    "accession": accession,
                    "date": record_date,
                    "topology": topology,
                    "taxonomy": taxonomy,
                    "source": source,
                    "data_file_division": data_file_division,
                }
            )

            #CDS feature to the SeqRecord
            new_record.features.append(cds_feature)
            te_annotations.append(new_record)

#Write the TE annotations to a new GenBank file
with open("/Users/xanderlee/Desktop/Honours/Database/updated_TnCentral_annotation_genbank.gbff", "w") as output_file:
    SeqIO.write(te_annotations, output_file, "genbank")
# Out:
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                8525 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '8525' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                6418 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '6418' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                8107 bp DNA     linear   BCT 08-MAY-2021\n'
# Found locus 'Exported' size '8107' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                8781 bp DNA     linear   BCT 08-MAY-2021\n'
# Found locus 'Exported' size '8781' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:188: BiopythonParserWarning: line too short to contain a feature: 'xxxx'
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               11000 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '11000' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               17336 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '17336' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                6669 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '6669' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                6266 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '6266' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                9443 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '9443' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               14193 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '14193' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                3989 bp DNA     linear   BCT 08-MAY-2021\n'
# Found locus 'Exported' size '3989' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               17530 bp DNA     linear   BCT 10-JUN-2022\n'
# Found locus 'Exported' size '17530' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               11547 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '11547' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               13188 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '13188' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                7180 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '7180' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                8346 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '8346' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                8330 bp DNA     linear   BCT 01-JUN-2022\n'
# Found locus 'Exported' size '8330' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                7572 bp DNA     linear   BCT 02-JUN-2022\n'
# Found locus 'Exported' size '7572' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               10245 bp DNA     linear   BCT 02-JUN-2022\n'
# Found locus 'Exported' size '10245' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported                8768 bp DNA     linear   PLN 02-JUN-2022\n'
# Found locus 'Exported' size '8768' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               13029 bp DNA     linear   BCT 10-JUN-2022\n'
# Found locus 'Exported' size '13029' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# /Users/xanderlee/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:1529: BiopythonParserWarning: Attempting to parse malformed locus line:
# 'LOCUS       Exported               10953 bp DNA     linear   BCT 02-JUN-2022\n'
# Found locus 'Exported' size '10953' residue_type 'DNA'
# Some fields may be wrong.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/xanderlee/Desktop/Honours/Database/Script/Genbank_extractor.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/xanderlee/Desktop/Honours/Database/Script/Genbank_extractor.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> te_annotations = []
#      <a href='vscode-notebook-cell:/Users/xanderlee/Desktop/Honours/Database/Script/Genbank_extractor.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> #Parse the multi-GenBank file and extract relevant TE annotations
# ---> <a href='vscode-notebook-cell:/Users/xanderlee/Desktop/Honours/Database/Script/Genbank_extractor.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> for index, record in enumerate(SeqIO.parse(multigenbank_file, "genbank")):
#      <a href='vscode-notebook-cell:/Users/xanderlee/Desktop/Honours/Database/Script/Genbank_extractor.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a>
#      <a href='vscode-notebook-cell:/Users/xanderlee/Desktop/Honours/Database/Script/Genbank_extractor.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a>     #Get the date or set default to "unknown"
#      <a href='vscode-notebook-cell:/Users/xanderlee/Desktop/Honours/Database/Script/Genbank_extractor.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a>     record_date = record.annotations.get("date", "unknown")
#      <a href='vscode-notebook-cell:/Users/xanderlee/Desktop/Honours/Database/Script/Genbank_extractor.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a>     #Get the topology or set default to "unknown"
#
# File ~/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/SeqIO/Interfaces.py:72, in SequenceIterator.__next__(self)
#      70 """Return the next entry."""
#      71 try:
# ---> 72     return next(self.records)
#      73 except Exception:
#      74     if self.should_close_stream:
#
# File ~/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:516, in InsdcScanner.parse_records(self, handle, do_features)
#     514 with as_handle(handle) as handle:
#     515     while True:
# --> 516         record = self.parse(handle, do_features)
#     517         if record is None:
#     518             break
#
# File ~/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:499, in InsdcScanner.parse(self, handle, do_features)
#     493 from Bio.GenBank.utils import FeatureValueCleaner
#     495 consumer = _FeatureConsumer(
#     496     use_fuzziness=1, feature_cleaner=FeatureValueCleaner()
#     497 )
# --> 499 if self.feed(handle, consumer, do_features):
#     500     return consumer.data
#     501 else:
#
# File ~/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:470, in InsdcScanner.feed(self, handle, consumer, do_features)
#     468 # Features (common to both EMBL and GenBank):
#     469 if do_features:
# --> 470     self._feed_feature_table(consumer, self.parse_features(skip=False))
#     471 else:
#     472     self.parse_features(skip=True)  # ignore the data
#
# File ~/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:230, in InsdcScanner.parse_features(self, skip)
#     228             feature_lines.append(line[self.FEATURE_QUALIFIER_INDENT :].strip())
#     229             line = self.handle.readline()
# --> 230         features.append(self.parse_feature(feature_key, feature_lines))
#     231 self.line = line
#     232 return features
#
# File ~/anaconda3/envs/bioinf/lib/python3.11/site-packages/Bio/GenBank/Scanner.py:366, in InsdcScanner.parse_feature(self, feature_key, lines)
#     363     return feature_key, feature_location, qualifiers
#     364 except StopIteration:
#     365     # Bummer
# --> 366     raise ValueError(
#     367         "Problem with '%s' feature:\n%s" % (feature_key, "\n".join(lines))
#     368     ) from None
#
# ValueError: Problem with 'misc_feature' feature:
# 1..441
# /note="identical to sequence adjacent to 3'-CS of In3
